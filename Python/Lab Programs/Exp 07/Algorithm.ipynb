# %% [markdown]
# ### **Algorithm: Sum of Even Natural Numbers up to n**
#
# 1. **Start**
# 2. **Input** a number **n**
# 3. **Initialize** `sum = 0`
# 4. **Initialize** `i = 1`
# 5. **While** `i ≤ n`, repeat:
#
#    * If `i % 2 == 0`, then
#
#      * Add `i` to `sum`
#    * Increment `i`
# 6. **Display** `sum`
# 7. **Stop**
