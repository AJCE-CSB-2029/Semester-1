# %% [markdown]
# ### **Algorithm: Arithmetic Operations using Python**
#
# 1. **Start**
# 2. **Input** a and b
# 4. **Compute**
#
#    * `sum = a + b`
#    * `diff = a - b`
#    * `prod = a * b`
#    * `div = a / b`
#    * `mod = a % b`
#    * `floor_div = a // b`
#    * `exp = a ** b`
#
# 5. **Display** all the results:
# 6. **Stop**
