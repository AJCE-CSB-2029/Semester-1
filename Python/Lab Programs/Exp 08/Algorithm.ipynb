# %% [markdown]
# ### **Algorithm: Sum of Even and Odd Natural Numbers up to n**
#
# 1. **Start**
# 2. **Input** a number **n**
# 3. **Initialize**
#
#    * `even_sum = 0`
#    * `odd_sum = 0`
#    * `i = 1`
# 4. **While** `i ≤ n`, repeat:
#
#    * If `i % 2 == 0`, add `i` to `even_sum`
#    * Else, add `i` to `odd_sum`
#    * Increment `i`
# 5. **Display** `even_sum` and `odd_sum`
# 6. **Stop**
