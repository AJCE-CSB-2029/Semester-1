# %% [markdown]
# ### **Algorithm: Sum of n Natural Numbers**
#
# 1. **Start**
#
# 2. **Input** a number **n**
# 3. **Initialize** `sum = 0`
# 4. **Initialize** `i = 1`
# 5. **While** `i ≤ n`, repeat:
#
#    * Add `i` to `sum`
#    * Increment `i` by 1
# 6. **Display** the value of **sum**
# 7. **Stop**
