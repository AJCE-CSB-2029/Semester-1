# %% [markdown]
# ### **Algorithm: Odd or Even Number**
#
# 1. **Start**
#
# 2. **Input** a number → store in **n**
# 3. **Compute** `n % 2`
# 4. **If** the remainder is **0**, then
#    → The number is **Even**
#    **Else**
#    → The number is **Odd**
# 5. **Display** the result
# 6. **Stop**
