# %% [markdown]
# ### **Algorithm 1: Find Largest and Smallest Number in a List Using Built-in Functions**
#
# 1. **Start**
#
# 2. **Input** a list of numbers → `numbers`
# 3. **Find** the largest number using `max(numbers)` and store in `largest`
# 4. **Find** the smallest number using `min(numbers)` and store in `smallest`
# 5. **Display** the largest number
# 6. **Display** the smallest number
# 7. **Stop**
#
# ---
#
# ### **Algorithm 2: Find Largest and Smallest Element in a List Without Built-in Functions**
#
# 1. **Start**
# 2. **Input** a list of numbers → `numbers`
# 3. **Initialize**
#
#    * `largest = numbers[0]`
#    * `smallest = numbers[0]`
# 4. **For each element** `num` in `numbers`, do:
#
#    * If `num > largest`, then set `largest = num`
#    * If `num < smallest`, then set `smallest = num`
# 5. **Display** the value of `largest`
# 6. **Display** the value of `smallest`
# 7. **Stop**
